# %% [markdown]
# <a href="https://colab.research.google.com/github/cenxunxun/douban2notion/blob/main/notebooks/run_Cellpose-SAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-6bm8b3nk
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-6bm8b3nk
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit 6d23968d924fc3b8e419a2d79349888f4b07aa29
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (1.16.3)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (2026.1.14)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (0.24.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (4.13.0.90)
# Requirement already satisfied: fastremap in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (1.17.7)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (2026.1.14)
# Requirement already satisfied: roifile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (2026.1.29)
# Requirement already satisfied: fill-voids in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (2.1.1)
# Requirement already satisfied: segment_anything in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.9.dev5+g6d23968d9) (1.0)
# Requirement already satisfied: torch==2.9.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.9.dev5+g6d23968d9) (2.9.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.9.dev5+g6d23968d9) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.9.0->torchvision->cellpose==4.0.9.dev5+g6d23968d9) (3.0.3)

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# 2026-02-01 07:52:26,945 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2026-02-01 07:52:26,947 [INFO]
# cellpose version: 	4.0.9.dev5+g6d23968d9
# platform:       	linux
# python version: 	3.12.12
# torch version:  	2.9.0+cu126
# 2026-02-01 07:52:26,948 [INFO] ** TORCH CUDA version installed and working. **
# 2026-02-01 07:52:26,951 [INFO] ** TORCH CUDA version installed and working. **
# 2026-02-01 07:52:26,952 [INFO] >>>> using GPU (CUDA)
# 2026-02-01 07:52:31,460 [INFO] >>>> loading model /root/.cellpose/models/cpsam

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/images"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".png"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 3 images in folder:
# img01.png
# img07.png
# test.png

# %%
import os
from tqdm import tqdm # 用于显示进度条
from skimage import io

# 1. 定义输出文件夹路径
output_dir = dir / "output_masks"
output_dir.mkdir(parents=True, exist_ok=True) # 如果文件夹不存在则创建

print(f"开始处理，结果将保存至: {output_dir}")

# 2. 确定保存格式
masks_ext = ".png" if image_ext == ".png" else ".tif"
first_channel, second_channel, third_channel = 0,1,2
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

# 3. 循环处理所有文件
for f in tqdm(files):
    # 读取当前图像
    img = io.imread(f)

    # 频道选择逻辑（适配你的 img_selected_channels 逻辑）
    # 注意：这里假设所有图片的通道数一致，如果不一致，需要在循环内动态判断
    img_selected_channels = np.zeros_like(img)
    img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]

    # 模型预测
    masks, flows, styles = model.eval(
        img_selected_channels,
        batch_size=32,
        flow_threshold=flow_threshold,
        cellprob_threshold=cellprob_threshold,
        normalize={"tile_norm_blocksize": tile_norm_blocksize}
    )

    # 4. 保存结果到 output_masks 文件夹
    # 保存为单通道 16-bit 或 8-bit 的标签图（Labels），方便后续量化分析
    save_path = output_dir / (f.stem + "_masks" + masks_ext)
    io.imsave(str(save_path), masks.astype(np.uint16), check_contrast=False)

print(f"任务完成！所有掩膜已保存至 {output_dir}")
# Out:
# 开始处理，结果将保存至: /content/images/output_masks
# 2026-02-01 08:04:59,853 [WARNING] Found more than 3 channels, only using first 3
# 2026-02-01 08:04:59,858 [INFO] processing image with (437, 600) HW, and 3 channels
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2026-02-01 08:05:03,027 [INFO] processing image with (457, 609) HW, and 3 channels
#  33%|███▎      | 1/3 [00:03<00:06,  3.27s/it]
# 2026-02-01 08:05:06,299 [INFO] processing image with (333, 502) HW, and 3 channels
#  67%|██████▋   | 2/3 [00:05<00:02,  2.56s/it]
# 2026-02-01 08:05:08,354 [WARNING] Found more than 3 channels, only using first 3
# 2026-02-01 08:05:08,357 [INFO] processing image with (437, 600) HW, and 3 channels
# 100%|██████████| 3/3 [00:08<00:00,  2.81s/it]
# 任务完成！所有掩膜已保存至 /content/images/output_masks

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (437, 600, 3). Assuming channel dimension is last with 3 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
first_channel, second_channel, third_channel = 0,1,2
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()
# Out:
# 2026-02-01 07:54:28,498 [INFO] processing image with (437, 600) HW, and 3 channels

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-02-01 07:55:30,599 [INFO] processing image with (437, 600) HW, and 3 channels
# 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 1/1 [00:00<00:00, 98.82it/s]
# running cellpose-SAM
# 2026-02-01 07:55:36,368 [INFO] processing image with (437, 600) HW, and 3 channels
# saving masks
# 100%|██████████| 1/1 [00:00<00:00, 289.36it/s]

# %% [markdown]
# to save your masks for ImageJ, run the following code:

# %%
for i in trange(len(files)):
    f = files[i]
    masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
    io.save_rois(masks0, f)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2097306421.py in <cell line: 0>()
#       1 for i in trange(len(files)):
#       2     f = files[i]
# ----> 3     masks0 = io.imsave(dir / (f.name + "_masks" + masks_ext))
#       4     io.save_rois(masks0, f)
#
# TypeError: imsave() missing 1 required positional argument: 'arr'
